# %% [markdown]
# <div style="position: relative; width: 100%; height: 100vh; padding: 50px; box-sizing: border-box;">
#     <!-- Logo positioned in the right corner -->
#     <img src="logo.png" style="position: absolute; top: 10px; right: 10px; width: 100px;"/>
#
#    <!-- Proprietary Content -->
#    <div style="position: absolute; bottom: px5; left: 5%; transform: translateX(-50%); color: grey; text-align: left;font-style: italic">
#    <p>Proprietary content. © 10xTechClub. All Rights Reserved. Unauthorized use or distribution prohibited.</p>
#    </div>
# </div>

# %% [markdown]
# ## <span style="color:green">Session 1 - Introduction to Python

# %% [markdown]
# # <span style="color:blue">What is Python?
# Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python's design philosophy emphasizes code readability and simplicity, making it an ideal choice for both beginners and experienced programmers.

# %% [markdown]
# ## <span style="color:blue"> Let's try our first python code.
# ![image.png](attachment:072da349-6b3a-4127-8052-35f2a1b41824.png)

# %% [markdown]
# <span style="color:red">In Python, anything inside print() is displayed on the screen.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # <span style="color:blue">Python Variables
# A variable in Python is a name that is used to refer to memory location. It is a way to store data for later use in your program. Variables are essential in programming as they allow you to store, retrieve, and manipulate data.

# %% [markdown]
# # <span style="color:blue">Python Datatypes
# Python provides a variety of data types to handle different kinds of data. Understanding these data types is essential for effective programming in Python. Here's an overview of the main data types in Python:
#
# 1. Numeric Types:
# int: Represents whole numbers without a fractional part. Examples include 5, -10, and 0.
# float: Represents numbers with a fractional part. Examples include 3.14, -0.001.
# complex: Represents complex numbers with real and imaginary parts. Examples include 1 + 2j.
#
# 2. str (String): A sequence of characters enclosed in single, double, or triple quotes. Examples include "hello", 'Python'.
#
# 3. Boolean Type:
# bool: Represents one of two values: True or False.
#
# 4. list: An ordered collection of items, which can be of different types. Lists are mutable, meaning their content can be changed. Examples include [1, 2, 3], ["apple", "banana"].
#
# 5. dict (Dictionary): A collection of key-value pairs. Dictionaries are unordered and mutable. Examples include {"name": "Alice", "age": 25}.

# %% [markdown]
# #### <span style="color:red"> Integer variable

# %%
a = 10
print(a)
# Out:
# 10

# %% [markdown]
# #### <span style="color:red"> Float variable

# %%
c = 3.14
print(c)
# Out:
# 3.14

# %% [markdown]
# #### <span style="color:red"> Boolean variable

# %%
is_active = False
print(is_active)
# Out:
# False

# %% [markdown]
# #### <span style="color:red"> String variable
# String variables can be declared either by using single or double quotes

# %%
name = "Alice"
greeting = 'Good day!'
print(greeting, name)
# Out:
# Good day! Alice

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red"> 1.Assign the value 25 to a variable named age and print the value of age.

# %% [markdown]
# #### <span style="color:red">  2. Assign the value 9.81 to a variable named gravity and print the value of gravity.

# %% [markdown]
# #### <span style="color:red">  3. Assign the value True to a variable named is_logged_in and print the value of is_logged_in.

# %% [markdown]
# #### <span style="color:red">  4.Assign the string "Bob" to a variable named student_name and the string "Hello" to a variable named message. Then, print both message and student_name in a single print statement.

# %% [markdown]
# ## <span style="color:blue"> Output variable
# -In the print() function, you output multiple variables, separated by a comma.<br>
# -You can also use the + operator to output multiple variables.

# %%
x = "The"
y = "Solar"
z = "System"
print(x, y, z)
print(x + y +z)
# Out:
# The Solar System
# TheSolarSystem

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red"> 1. Assign the string "Welcome" to a variable named g and the string "Home" to a variable named h. Print the variables g and h in a single print statement, separated by a comma.

# %% [markdown]
# #### <span style="color:red"> 2. Assign the string "Data" to a variable named i, the string "Science" to a variable named j, and the string "Rocks" to a variable named k. Print the concatenated result of i, j, and k with spaces in between.

# %% [markdown]
# #### <span style="color:red"> 3. Assign the string "Open" to a variable named v and the string "House" to a variable named w. Print the concatenated result of v and w with a space in between.

# %% [markdown]
# ## <span style="color:blue"> Type method
# You can get the data type of a variable with the type() function.

# %%
x = 98
y = "10xTech"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red"> 1. You are given a string s = "1234". Write a Python program to convert this string into an integer and a float, and then print the results along with their types.

# %% [markdown]
# #### <span style="color:red"> 2. Assign the value True to a variable named is_active and the string "Active" to a variable named status. Print the types of both variables.

# %% [markdown]
# #### <span style="color:red"> 3.Assign the value 256 to a variable named pages and the string "Book" to a variable named title. Print the types of both variables.

# %% [markdown]
# # <span style="color:blue">Python Variable Rules
# 1. Variable Names Must Start with a Letter or Underscore (_)
# 2. Variable Names Can Contain Letters, Numbers, and Underscores
# 3. Variable Names are Case-Sensitive
# 4. Variable Names Cannot be Python Keywords
# 5. Variable Names Should be Descriptive
# 6. Variable Names cannot have space in between.

# %% [markdown]
# #### <span style="color:red"> Legal Variable Names

# %%
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %% [markdown]
# ## <span style="color:blue"> Python Variables - Assign Multiple Values

# %% [markdown]
# ## <span style="color:blue"> Many Values to Multiple Variables

# %%
x, y, z = "Mercury", "Venus", "Earth"
print(x)
print(y)
print(z)
# Out:
# Mercury
# Venus
# Earth

# %% [markdown]
# ## <span style="color:blue"> One Value to Multiple Variables

# %%
x = y = z = "Jupiter"
print(x)
print(y)
print(z)
# Out:
# Jupiter
# Jupiter
# Jupiter

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red">1.Write a Python program to swap the values of two variables x = 10 and y = 20 without using a temporary variable. Print the values of x and y before and after swapping.

# %% [markdown]
# #### <span style="color:red"> 2. Assign the values "Dog", "Cat", and "Rabbit" to variables named pet1, pet2, and pet3 respectively. Print each variable on a new line.

# %% [markdown]
# #### <span style="color:red"> 3.Assign the values "Monday", "Tuesday", and "Wednesday" to variables named day1, day2, and day3 respectively. Print each variable on a new line.

# %% [markdown]
# #### <span style="color:red">4.Assign the value "Football" to variables named sport1, sport2, and sport3 using the method demonstrated in the code snippet. Print each variable on a new line.

# %% [markdown]
# #### <span style="color:red"> 5. Assign the value "Python" to variables named language1, language2, and language3 using the method demonstrated in the code snippet. Print each variable on a new line.

# %% [markdown]
# ## <span style="color:blue"> Type Conversion/ Type Casting
# You can convert from one type to another with the int(), float(), and complex() methods

# %%
# Initial values
x = 5       # int
y = 3.7     # float
z = 5 + 3j  # complex

# Convert from int to float
a = float(x)

# Convert from float to int
b = int(y)

# Convert from complex to int (taking the real part only)
c = int(z.real)

# Convert from int to string
d = str(x)

# Convert from float to string
e = str(y)

# Convert from complex to string
f = str(z)

# Print the converted values
print(a)  # Output: 5.0
print(b)  # Output: 3
print(c)  # Output: 5
print(d)  # Output: '5'
print(e)  # Output: '3.7'
print(f)  # Output: '(5+3j)'

# Print the types of the converted values
print(type(a))  # Output: <class 'float'>
print(type(b))  # Output: <class 'int'>
print(type(c))  # Output: <class 'int'>
print(type(d))  # Output: <class 'str'>
print(type(e))  # Output: <class 'str'>
print(type(f))  # Output: <class 'str'>
# Out:
# 5.0
# 3
# 5
# 5
# 3.7
# (5+3j)
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x = float(1)     # x will be 1.0
y = float(2.8)   # y will be 2.8
z = float("3")   # z will be 3.0
w = float("4.2") # w will be 4.2

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red">1. Convert the integer 10 to a float and print the result.

# %% [markdown]
# #### <span style="color:red">2. Convert the float 7.5 to an integer and print the result.

# %% [markdown]
# #### <span style="color:red">3. Convert the string "15" to an integer and print the result.

# %% [markdown]
# # <span style="color:blue">Python Comments
# Comments can be used to explain Python code.
#
# Comments can be used to make the code more readable.
#
# Comments can be used to prevent execution when testing code.

# %% [markdown]
# <span style="color:red">Comments starts with a #, and Python will ignore them

# %%
#This is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # <span style="color:blue"> Multiline Comments
# <span style="color:red"> To add a multiline comment you could insert a # for each line or  you can add a multiline string (triple quotes """) in your code, and place your comment inside it

# %%
#This is a comment
#written in
#more than just one line
print("Hello, World!")
# Out:
# Hello, World!

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## <span style="color:blue"> -----------END OF CLASS-----------

# %% [markdown]
# # <span style="color:red"> Assignment questions

# %% [markdown]
# 1. Assign the value False to a variable named is_member and print a message "Membership status: False" using the is_member variable in the print statement.

# %% [markdown]
# 2. Assign the value 100 to a variable named score and the string "Congratulations!" to a variable named congrats_message. Then, print the message "Your score is 100. Congratulations!" using both variables in a single print statement.

# %% [markdown]
# 3. Assign the string "Happy" to a variable named p and the string "Birthday" to a variable named q. Print the concatenated result of p and q with a space in between.

# %% [markdown]
# 4. Assign the value 9.81 to a variable named gravity and the string "Gravity" to a variable named gravity_string. Print the types of both variables.

# %% [markdown]
# 5. Assign the values "January", "February", and "March" to variables named month1, month2, and month3 respectively. Print each variable on a new line.

# %% [markdown]
# 6. Convert the string "8.5" to a float and print the result.

# %% [markdown]
# <div style="position: relative; width: 100%; height: 100vh; padding: 50px; box-sizing: border-box;">
#
#
#    <!-- Proprietary Content -->
#    <div style="position: absolute; bottom: px5; left: 20%; transform: translateX(-50%); color: grey; text-align: centre;font-style: italic">
#    <p>Proprietary content. © 10xTechClub. All Rights Reserved. Unauthorized use or distribution prohibited.</p>
#    </div>
# </div>
