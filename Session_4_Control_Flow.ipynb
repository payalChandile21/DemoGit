# %% [markdown]
# <div style="position: relative; width: 100%; height: 100vh; padding: 50px; box-sizing: border-box;">
#     <!-- Logo positioned in the right corner -->
#     <img src="logo.png" style="position: absolute; top: 10px; right: 10px; width: 100px;"/>
#
#    <!-- Proprietary Content -->
#    <div style="position: absolute; bottom: px5; left: 5%; transform: translateX(-50%); color: grey; text-align: left;font-style: italic">
#    <p>Proprietary content. © 10xTechClub. All Rights Reserved. Unauthorized use or distribution prohibited.</p>
#    </div>
# </div>

# %% [markdown]
# ## <span style="color:green"> Session 4 - Control Flow in Python

# %% [markdown]
# # <span style="color:blue">Python if...else Statement
# In computer programming, the if statement is a conditional statement. It is used to execute a block of code only when a specific condition is met. For example,
#
# Suppose we need to assign different grades to students based on their scores.
#
# - If a student scores above 90, assign grade A
# - If a student scores above 75, assign grade B
# - If a student scores above 65, assign grade C
# - These conditional tasks can be achieved using the if statement.

# %% [markdown]
# ## <span style="color:blue"> Python if Statement
# An if statement executes a block of code only if the specified condition is true.

# %% [markdown]
# #### Syntax

# %% [markdown]
# ![image.png](attachment:5fc54939-c7b4-4b52-b5fb-358e1a91498c.png)

# %% [markdown]
# Here, if the condition of the if statement is:
#
# - True - the body of the if statement executes.
# - False - the body of the if statement is skipped from execution.

# %% [markdown]
# ## <span style="color:blue"> Let's try a few examples with if condition and explore comparison operators.

# %% [markdown]
# <span style="color:red">Demonstrating the use of less than ' < ' operator

# %%
#using less than ('<')
number = 10

# Check if number is less than 20
if number < 20:
    print('Number is less than 20')

print('This statement always executes')
# Out:
# Number is less than 20
# This statement always executes

# %% [markdown]
# <span style="color:red"> Demonstrating the use of greater than equal '>=' operator

# %%
#Greater than equal to ('>=')
number = 10

# Check if number is greater than or equal to 10
if number >= 10:
    print('Number is 10 or greater')

print('This statement always executes')
# Out:
# Number is 10 or greater
# This statement always executes

# %% [markdown]
# <span style="color:red"> Demonstrating the use of less than equal '<=' operator

# %%
#Less than or equal to ('<=')
number = 10

# Check if number is less than or equal to 10
if number <= 10:
    print('Number is 10 or less')

print('This statement always executes')
# Out:
# Number is 10 or less
# This statement always executes

# %% [markdown]
# <span style="color:red"> Demonstrating the use of equal to '==' operator

# %%
#equal to ('==')
number = 10

# Check if number is equal to 10
if number == 10:
    print('Number is exactly 10')

print('This statement always executes')
# Out:
# Number is exactly 10
# This statement always executes

# %% [markdown]
# <span style="color:red"> Demonstrating the use of not equal to '!=' operator

# %%
#not equal to ('!=')
number = 10

# Check if number is not equal to 5
if number != 5:
    print('Number is not 5')

print('This statement always executes')
# Out:
# Number is not 5
# This statement always executes

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red"> 1. Write a Python program that checks whether a given number is positive or negative.

# %% [markdown]
# #### <span style="color:red">2. Write a Python program that takes a number as input from the user and checks if the number is even.

# %% [markdown]
# #### <span style="color:red">3. Write a Python program that takes a password as input from the user and checks if the password is at least 8 characters long

# %% [markdown]
# ## <span style="color:blue"> Python if...else Statement
# An if statement can have an optional else clause. The else statement executes if the condition in the if statement evaluates to False.

# %% [markdown]
# ![image.png](attachment:84ba7253-a7b9-43ba-89e9-bc4d70a49b03.png)

# %% [markdown]
# ## <span style="color:blue"> Let's try a few examples with membership in list .

# %% [markdown]
# <span style="color:red">  Demonstrating if-else

# %%
#Equality (==)
number = 10

# Check if number is equal to 10
if number == 10:
    print('Number is exactly 10')
else:
    print('Number is not 10')

print('This statement always executes')

# %%
#Inequality (!=)
number = 10

# Check if number is not equal to 5
if number != 5:
    print('Number is not 5')
else:
    print('Number is 5')

print('This statement always executes')

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red">1.Write a Python program that takes an age as input from the user and checks if the user is eligible to vote. If the age is 18 or older, print a message indicating that the user is eligible to vote. Otherwise, print a message indicating that the user is not eligible to vote.

# %%
# Get age as input from the user

# Check if the user is eligible to vote

# %% [markdown]
# #### <span style="color:red">2. Write a Python program that takes a string as input from the user and checks if the string is a palindrome.

# %%
# Get a string from the user

# Check if the string is a palindrome

# %% [markdown]
# #### <span style="color:red">3. Write a Python program that takes a number as input from the user and checks if the number is a perfect square.

# %% [markdown]
# ![image.png](attachment:09f06967-05f2-4697-93d1-dff3ec21bf68.png)

# %%
# Get a number as input from the user


# Check if the number is a perfect square

# %% [markdown]
# #### <span style="color:red">4. Write a Python program to check the boolean value of variable

# %%
#Checking for Boolean Value


# Check if is_active is True

# %% [markdown]
# #### <span style="color:red">5. Write a Python program to check whether a string is a palindrome or not.

# %% [markdown]
# ![image.png](attachment:4368ffdc-4947-40a5-9858-0358d61bf7b0.png)

# %%
# Get a string from the user


# Check if the string is a palindrome

# %% [markdown]
# ## <span style="color:blue"> Python if...elif...else Statement

# %% [markdown]
# ![image.png](attachment:933f3edb-e747-48cd-aa26-7a2b29070cf5.png)

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red">1. Write a Python program that checks if a given number is positive, negative, or zero. Print an appropriate message based on the value of the number.

# %% [markdown]
# #### <span style="color:red">2. Write a Python program that checks if a character is uppercase, lowercase, or not a Letter

# %% [markdown]
# #### <span style="color:red">3. Create a BMI (Body Mass Index) calculator that takes a person's weight (in kilograms) and height (in meters) as input. Based on their BMI value, classify them as underweight, normal weight, overweight, or obese using if-elif-else.

# %% [markdown]
# ## <span style="color:blue"> Let's try a few examples with membership in list .
# in returns True if a sequence with the specified value is present in the object

# %% [markdown]
# #### <span style="color:red"> 1. Write a python program to check if the number is present in the list.

# %%
#Checking Membership in a List ('in')
number = 10
numbers_list = [1, 2, 10, 20]

# Check if number is in the list
if number in numbers_list:
    print('Number is in the list')

print('This statement always executes')

# %% [markdown]
# #### <span style="color:red">2. Write a python program to check if a string contains, starts with, or ends with a substring

# %% [markdown]
# ![image.png](attachment:05dda1c6-27ae-406d-9637-ea2e033015ab.png)

# %%
# Get a string and a substring from the user
main_string = input("Enter the main string: ")
substring = input("Enter the substring: ")

# Check if the substring is in the main string, starts with, or ends with it

if main_string.startswith(substring):
    print(f"The main string starts with '{substring}'.")
elif main_string.endswith(substring):
    print(f"The main string ends with '{substring}'.")
elif substring in main_string:
    print(f"The substring '{substring}' is found in the main string.")
else:
    print(f"The substring '{substring}' is not found in the main string.")
# Out:
# Enter the main string:  ghat
# Enter the substring:  ha
# The substring 'ha' is found in the main string.

# %% [markdown]
# ## <span style="color:blue">Logical Operators (AND, OR, NOT)

# %% [markdown]
# 1. The And operator is used to verify where both conditions associated with it are True Simultaneously. It is represented as "X and Y".
# 2. The Or Operator is used to verify that either of the associated conditions is true. It is represented as "X or Y".
# 3. The Not Operator is associated with a single condition. It inverts the results, i.e., true is changed to false, and false is changed to true. It is represented as "not X".

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red">1. Write a python program to take a year as input from the user and check if the year is a leap year or not.

# %% [markdown]
# ![image.png](attachment:f6deb869-33cb-4130-afff-e63449fc2e4b.png)

# %%
# Get the year from the user
year = int(input("Enter a year: "))

# Check if it's a leap year

# %% [markdown]
# #### <span style="color:red">2. Write a Python program that takes a student's test score as input and determines their grade using if-elif-else statements. The grading scale is A for 90-100, B for 80-89, C for 70-79, D for 60-69, and F for scores below 60.

# %%
#Check marks

# %% [markdown]
# #### <span style="color:red">3. Create a program that checks if a given letter is a vowel (a, e, i, o, u). Use if-elif-else statements to make the determination.​

# %%
# Get a letter as input from the user


# Convert the input to lowercase to handle both upper and lower case letters

# Check if the letter is a vowel

# %% [markdown]
# ## <span style="color:blue"> NESTED if...else

# %% [markdown]
# ![image.png](attachment:d4d01ab4-9012-4772-8223-0304f09809f1.png)

# %% [markdown]
# ## <span style="color:blue">Let's try a few examples

# %% [markdown]
# <span style="color:red"> Write a Python program that checks if a given number is positive, negative, or zero using nested if statements. Print an appropriate message based on the value of the number.

# %%
number = 5

# outer if statement
if number >= 0:
    # inner if statement
    if number == 0:
      print('Number is 0')
    
    # inner else statement
    else:
        print('Number is positive')

# outer else statement
else:
    print('Number is negative')

# %% [markdown]
# <span style="color:red"> Write a Python program that uses nested if-else statements to check if a given number is positive, negative, or zero. Print an appropriate message based on the value of the number, and include a statement that always executes regardless of the number's value.

# %%
#Greater Than (>)
number = 10

# Nested if-else for checking if number is greater than 0
if number > 0:
    print('Number is positive')
else:
    if number == 0:
        print('Number is zero')
    else:
        print('Number is negative')

print('This statement always executes')

# %% [markdown]
# ## <span style="color:blue">PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red">1. Write a Python program that suggests a meal based on dietary preferences. Ask the user if they are vegetarian, vegan, or non-vegetarian and if they prefer spicy or non-spicy food. Use logical operators in if-elif-else statements to generate meal suggestions.

# %%
# Get user preferences
is_vegetarian = input("Are you vegetarian? (yes/no): ").lower()
is_vegan = input("Are you vegan? (yes/no): ").lower()
spicy_preference = input("Do you prefer spicy food? (yes/no): ").lower()

# Initialize meal suggestion
meal_suggestion = "Meal suggestion: "

# Check dietary preferences and generate suggestions



# Add spiciness preference


# Display the meal suggestion
print(meal_suggestion)

# %% [markdown]
# #### <span style="color:red">2. Write a Python program that suggests a beverage based on the user's age and the current weather. The program should ask for the user's age and whether it is hot or cold outside. Based on the input, it should provide an appropriate beverage suggestion.

# %%
# Get user preferences
age = int(input("Enter your age: "))
weather = input("Is it hot or cold outside? (hot/cold): ").lower()

# Initialize beverage suggestion
beverage_suggestion = "Beverage suggestion: "

# Check age and weather to suggest a beverage


# Display the beverage suggestion
print(beverage_suggestion)

# %% [markdown]
# ## <span style="color:blue">match

# %% [markdown]
# ## <span style="color:blue">Let's try an example with match

# %% [markdown]
# ## <span style="color:blue"> PRACTICE QUESTIONS

# %% [markdown]
# #### <span style="color:red">1.Write a Python program that takes a day number as input from the user (1 for Monday, 2 for Tuesday, etc.) and determines the corresponding day of the week. If the input is not a valid day number (1-7), the program should print "Invalid day number".

# %%
# Get the day number from the user
day_number = int(input("Enter a day number (1 for Monday, 2 for Tuesday, etc.): "))

# Determine the corresponding day of the week


# Display the corresponding day of the week
print(f"The corresponding day of the week is {day}.")

# %% [markdown]
# #### <span style="color:red"> Using match statement

# %%
# Get the day number from the user
day_number = int(input("Enter a day number (1 for Monday, 2 for Tuesday, etc.): "))

# Determine the corresponding day of the week using match-case


# Display the corresponding day of the week
print(f"The corresponding day of the week is {day}.")

# %% [markdown]
# #### <span style="color:red">2.Write a Python program that takes a filename as input from the user and recognizes its file extension using the match statement.

# %%
# Get the filename from the user
filename = input("Enter a filename with extension: ")

# Determine the file extension using match-case

# Display the recognized file type
print(f"The file '{filename}' is recognized as a {file_type}.")

# %% [markdown]
# ## <span style="color:blue"> -----------END OF CLASS-----------

# %% [markdown]
# # <span style="color:red"> Assignment questions

# %% [markdown]
# 1. Write a Python program that takes a temperature in Celsius as input from the user and checks if the temperature is above the boiling point of water (100 degrees Celsius). If the temperature is above or equal to 100 degrees Celsius, print a message indicating that the temperature is above the boiling point of water.

# %%
# Get the temperature as input from the user

# Check if the temperature is above the boiling point of water

# %% [markdown]
# 2. Write python program to check if a Number is Even, Odd, or Zero.

# %%
# Get a number as input from the user

# Check if the number is even, odd, or zero

# %% [markdown]
# 3. Write a Python program that checks if a specific item is present in a list of fruits ['apple', 'banana', 'orange', 'grape', 'mango'] using the in operator.If the item is found, print a message "fruit_name is present in the list". Otherwise, print a message "fruit_name is absent in the list".

# %%
# Define a list of items



# Get an item from the user


# Check if the item is in the list

# %% [markdown]
# 4. Create a program that categorizes people into age groups. Ask the user to enter their age and use if-elif-else statements with logical operators to classify them as children (0-12), teenagers (13-19), adults (20-64), or seniors (65 and older).​

# %%
# Get the age from the user

# Categorize people into age groups


# Display the age group

# %% [markdown]
# 5. Write a Python program that suggests an activity based on the user's mood and the current time of day. The program should ask for the user's mood and the time of day, and then provide an appropriate activity suggestion based on the inputs.(Hint: Use nested if-else)

# %%
# Get user preferences


# Initialize activity suggestion


# Check mood and time of day to suggest an activity
 

# Display the activity suggestion

# %% [markdown]
# 6. Write a Python program that takes a month number (1 for January, 2 for February, etc.) as input from the user and determines the corresponding month name using the match statement. If the input month number is not valid (not between 1 and 12), the program should print "Invalid month number".

# %%
# Get the month number from the user

# Determine the corresponding month name using match-case

# Display the corresponding month name

# %% [markdown]
# <div style="position: relative; width: 100%; height: 100vh; padding: 50px; box-sizing: border-box;">
#    <!-- Proprietary Content -->
#    <div style="position: absolute; bottom: px5; left: 20%; transform: translateX(-50%); color: grey; text-align: left;font-style: italic">
#    <p>Proprietary content. © 10xTechClub. All Rights Reserved. Unauthorized use or distribution prohibited.</p>
#    </div>
# </div>
